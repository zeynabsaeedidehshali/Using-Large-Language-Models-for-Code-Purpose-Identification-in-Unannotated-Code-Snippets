# %%
# JAVA

# %%
# !pip install datasets pandas scikit-learn matplotlib torch
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
from datasets import load_dataset

# Step 2: Data Collection
# Specify the programming language for the dataset
language = "java"  # Choose from 'python', 'java', 'javascript', 'php', 'ruby', 'go'


# Load the dataset
dataset = load_dataset("code_search_net", language)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Generating train split:   0%|          | 0/454451 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/26909 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/15328 [00:00<?, ? examples/s]

# %%
# Explore the dataset
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 454451
#     })
#     test: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 26909
#     })
#     validation: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 15328
#     })
# })

# %%
train_df = dataset['train'].to_pandas()[['func_code_string','func_documentation_string']]
test_df = dataset['test'].to_pandas()[['func_code_string','func_documentation_string']]
validation_df = dataset['validation'].to_pandas()[['func_code_string','func_documentation_string']]

# %%
# Access the first example
first_example = train_df.iloc[0]
print("Docstring:\n", first_example['func_documentation_string'])
print()
print("Code:\n", first_example['func_code_string'])
# Out:
# Docstring:
#  calculates the convex hull of the specified array of points.
# <br>
# the array of points has to be of dimensions [n][2], <br>
# which means that a point can be obtained like this: <br>
# <code> double[] point = array[i]; </code><br>
# and coordinates like this: <br>
# <code> x= array[i][0] and y= array[i][1] </code>
#
# @param points in double[][]
# @return double[][] with points of the convex hull
#
# Code:
#  public List<Point2D> apply(PointFeature feature) {
#
#         List<Point2D> points = feature.getPoints();
#
#         if (points.size() < 4) {
#             return points;
#         }
#
#         Point2D pointOnHull = points.get(getIndexOfLeftMostPoint(points)); // leftmost point in shape
#
#         List<Point2D> hull = new ArrayList<Point2D>();
#
#         int i = 0;
#
#         Point2D endpoint = points.get(0); // initial endpoint for a candidate edge on the hull
#
#         do {
#
#             hull.add(pointOnHull);
#
#             endpoint = points.get(0);
#
#             for (int j = 1; j < points.size(); j++) {
#                 if (endpoint == pointOnHull || isLeftOfLine(points.get(j), hull.get(i), endpoint)) {
#                     endpoint = points.get(j); // found greater left turn, update endpoint
#                 }
#             }
#             i++;
#             pointOnHull = endpoint;
#
#         } while (endpoint != hull.get(0));
#
# 		/* i is now equal to the number of points of the hull.
# 		 * need to make correctly sized hull array now.
# 		 */
#         List<Point2D> hullToReturn = new ArrayList<Point2D>();
#
#         for (int k = 0; k < i; k++) {
#             hullToReturn.add(hull.get(k));
#         }
#
#         return hullToReturn;
#     }

# %%
#remove any non-english comments.
# From https://stackoverflow.com/a/27084708/5768407

def isASCII(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

train_df = train_df[train_df['func_documentation_string'].apply(lambda x: isASCII(x))]
test_df = test_df[test_df['func_documentation_string'].apply(lambda x: isASCII(x))]
validation_df = validation_df[validation_df['func_documentation_string'].apply(lambda x: isASCII(x))]

# %%
"""
any line with an @ symbol or curly braces, as that will significantlly lessen the amount of learning your model will have to do.
This also works out well since the JavaDoc syntax can usually be autogenerated from the method's signature.
#https://colab.research.google.com/github/ncoop57/i-am-a-nerd/blob/master/_notebooks/2020-03-07-How_to_Create_an_Automatic_Code_Comment_Generator_using_Deep_Learning.ipynb#scrollTo=r3sxnOlI7Hg2

"""
import re
from tqdm import tqdm
import pandas as pd

def filter_jdocs(df):
    methods = []
    comments = []
    for i, row in tqdm(list(df.iterrows())):
        comment = row["func_documentation_string"]
        # Remove {} text in comments from https://stackoverflow.com/questions/14596884/remove-text-between-and-in-python/14598135
        comment = re.sub("([\{\[]).*?([\)\}])", '', comment)


        cleaned = []
        for line in comment.split('\n'):
            if "@" in line: break
            cleaned.append(line)
        comments.append('\n'.join(cleaned))
        methods.append(row["func_code_string"])
    new_df = pd.DataFrame(zip(methods, comments), columns = ["func_code_string", "func_documentation_string"])

    return new_df

train_df = filter_jdocs(train_df);
test_df = filter_jdocs(test_df);
validation_df = filter_jdocs(validation_df);
# Out:
# 100%|██████████| 440332/440332 [00:05<00:00, 80704.27it/s]
# 100%|██████████| 26248/26248 [00:00<00:00, 105520.92it/s]
# 100%|██████████| 14197/14197 [00:00<00:00, 96615.16it/s]

# %%
# remove any empty comments or duplicate comments
train_df = train_df[~(train_df['func_documentation_string'] == '')]
test_df = test_df[~(test_df['func_documentation_string'] == '')]
validation_df = validation_df[~(validation_df['func_documentation_string'] == '')]

# %%
train_df = train_df[~train_df['func_documentation_string'].duplicated()]
test_df = test_df[~test_df['func_documentation_string'].duplicated()]
validation_df = validation_df[~validation_df['func_documentation_string'].duplicated()]

# %%
len(train_df), len(test_df), len(validation_df)
# Out:
# (331917, 21291, 11101)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
print(train_df.iloc[0]['func_code_string'])
# Out:
# public List<Point2D> apply(PointFeature feature) {
#
#         List<Point2D> points = feature.getPoints();
#
#         if (points.size() < 4) {
#             return points;
#         }
#
#         Point2D pointOnHull = points.get(getIndexOfLeftMostPoint(points)); // leftmost point in shape
#
#         List<Point2D> hull = new ArrayList<Point2D>();
#
#         int i = 0;
#
#         Point2D endpoint = points.get(0); // initial endpoint for a candidate edge on the hull
#
#         do {
#
#             hull.add(pointOnHull);
#
#             endpoint = points.get(0);
#
#             for (int j = 1; j < points.size(); j++) {
#                 if (endpoint == pointOnHull || isLeftOfLine(points.get(j), hull.get(i), endpoint)) {
#                     endpoint = points.get(j); // found greater left turn, update endpoint
#                 }
#             }
#             i++;
#             pointOnHull = endpoint;
#
#         } while (endpoint != hull.get(0));
#
# 		/* i is now equal to the number of points of the hull.
# 		 * need to make correctly sized hull array now.
# 		 */
#         List<Point2D> hullToReturn = new ArrayList<Point2D>();
#
#         for (int k = 0; k < i; k++) {
#             hullToReturn.add(hull.get(k));
#         }
#
#         return hullToReturn;
#     }

# %%
from huggingface_hub import snapshot_download, login

# %%
login(token="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")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "stabilityai/stable-code-3b"
# Source: https://huggingface.co/stabilityai/stable-code-3b


tokenizer = AutoTokenizer.from_pretrained(model_name)

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
).cuda()
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/4.76k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.47M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/602 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/29.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/610M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
def extract_line(full_output):
  # Now extract only the part after "Explanation:"
  if "Explanation:" in full_output:
    explanation_part = full_output.split("Explanation:", 1)[1].strip()
  else:
    explanation_part = full_output.strip()

  first_line = explanation_part.split('\n', 1)[0]
  return first_line

# %%
import re
from tqdm import tqdm
import pandas as pd

# %%
fraction = 1/40
sampled_test_df = test_df.sample(frac=fraction, random_state=42)
print(len(sampled_test_df))
# Out:
# 532

# %%
generated_comments = []
reference_comments = []

# Iterate over the test set
for _, row in tqdm(sampled_test_df.iterrows(), total=sampled_test_df.shape[0]):
    code = row['func_code_string']
    reference = row['func_documentation_string']

    prompt = f'Provide a detailed docstring for the following function:\n\n{code}\n\nDocstring:'


    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    # Generate the comment

    outputs = model.generate(
    **inputs,
    max_new_tokens=100,   # Control output length
    temperature=0.2,
    top_p=0.9,
    do_sample=True)
    output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    docstring = output.split('Docstring:')[-1].strip()

    # For example, if the docstring starts and ends with triple quotes, remove them
    if docstring.startswith('"""') and docstring.endswith('"""'):
      docstring = docstring[3:-3].strip()

    generated_comments.append(docstring)
    reference_comments.append(reference)
# Out:
#   0%|          | 0/532 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 1/532 [00:06<58:49,  6.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 2/532 [00:10<44:52,  5.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 3/532 [00:15<44:32,  5.05s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 4/532 [00:20<42:51,  4.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 5/532 [00:24<40:05,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 6/532 [00:29<41:13,  4.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|▏         | 7/532 [00:33<39:19,  4.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 8/532 [00:37<38:54,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 9/532 [00:42<40:08,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 10/532 [00:46<38:25,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 11/532 [00:51<38:29,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 12/532 [00:55<38:41,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 13/532 [00:59<37:16,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 14/532 [01:03<36:13,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 15/532 [01:08<37:37,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 16/532 [01:12<36:30,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 17/532 [01:16<35:49,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 18/532 [01:21<37:23,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▎         | 19/532 [01:25<36:47,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 20/532 [01:29<36:19,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 21/532 [01:34<38:15,  4.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 22/532 [01:38<36:53,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 23/532 [01:42<35:58,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 24/532 [01:47<37:44,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 25/532 [01:51<36:33,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 26/532 [01:55<36:02,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 27/532 [02:00<37:02,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 28/532 [02:04<37:55,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 29/532 [02:09<38:52,  4.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 30/532 [02:14<38:26,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 31/532 [02:18<37:08,  4.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 32/532 [02:24<40:01,  4.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 33/532 [02:28<38:01,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▋         | 34/532 [02:32<36:33,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 35/532 [02:37<39:23,  4.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 36/532 [02:41<37:29,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 37/532 [02:49<44:21,  5.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 38/532 [02:53<41:04,  4.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 39/532 [02:57<39:58,  4.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 40/532 [03:02<39:27,  4.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 41/532 [03:06<37:42,  4.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 42/532 [03:10<36:26,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 43/532 [03:15<37:02,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 44/532 [03:19<35:59,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 45/532 [03:23<35:31,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▊         | 46/532 [03:28<35:36,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 47/532 [03:32<34:35,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 48/532 [03:37<36:03,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 49/532 [03:46<47:26,  5.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 50/532 [03:51<46:20,  5.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 51/532 [03:57<46:25,  5.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 52/532 [04:01<42:17,  5.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 53/532 [04:06<40:06,  5.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 54/532 [04:10<37:14,  4.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 55/532 [04:14<35:56,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 56/532 [04:19<36:30,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 57/532 [04:22<34:34,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 58/532 [04:26<33:29,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 59/532 [04:31<34:02,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█▏        | 60/532 [04:35<32:54,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█▏        | 61/532 [04:39<31:56,  4.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 62/532 [04:43<32:57,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 63/532 [04:47<32:04,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 64/532 [04:54<38:34,  4.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 65/532 [04:58<36:36,  4.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 66/532 [05:03<36:06,  4.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 67/532 [05:07<36:04,  4.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 68/532 [05:11<34:12,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 69/532 [05:15<32:16,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 70/532 [05:19<33:12,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 71/532 [05:23<32:08,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▎        | 72/532 [05:27<32:00,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▎        | 73/532 [05:32<32:38,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 74/532 [05:36<32:12,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 75/532 [05:40<31:14,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 76/532 [05:44<32:18,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 77/532 [05:48<31:30,  4.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 78/532 [05:53<32:34,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 79/532 [05:57<33:01,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 80/532 [06:01<31:54,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 81/532 [06:05<31:23,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 82/532 [06:10<32:48,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 83/532 [06:14<31:49,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 84/532 [06:19<32:00,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 85/532 [06:23<32:42,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 86/532 [06:28<32:47,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▋        | 87/532 [06:32<31:35,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 88/532 [06:36<32:20,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 89/532 [06:41<32:05,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 90/532 [06:46<33:30,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 91/532 [06:50<33:26,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 92/532 [06:55<33:33,  4.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 93/532 [06:59<32:56,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 94/532 [07:03<32:08,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 95/532 [07:07<31:09,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 96/532 [07:12<32:49,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 97/532 [07:16<31:43,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 98/532 [07:20<30:48,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▊        | 99/532 [07:25<31:21,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 100/532 [07:29<30:02,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 101/532 [07:33<29:26,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 102/532 [07:37<30:03,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 103/532 [07:41<29:16,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 104/532 [07:45<28:39,  4.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 105/532 [07:50<31:20,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 106/532 [07:54<30:30,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 107/532 [07:59<32:10,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 108/532 [08:04<32:02,  4.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 109/532 [08:08<30:28,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 110/532 [08:11<29:43,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 111/532 [08:17<31:21,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 112/532 [08:20<30:04,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 113/532 [08:24<29:04,  4.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██▏       | 114/532 [08:30<31:37,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 115/532 [08:35<32:14,  4.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 116/532 [08:39<30:58,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 117/532 [08:43<31:12,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 118/532 [08:51<37:59,  5.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 119/532 [08:56<35:58,  5.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 120/532 [09:00<33:05,  4.82s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 121/532 [09:03<30:52,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 122/532 [09:08<31:14,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 123/532 [09:13<31:22,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 124/532 [09:17<30:05,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 125/532 [09:22<30:47,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▎       | 126/532 [09:26<30:18,  4.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 127/532 [09:30<29:14,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 128/532 [09:34<29:13,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 129/532 [09:38<28:15,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 130/532 [09:43<28:58,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 131/532 [09:47<29:02,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 132/532 [09:51<28:24,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 133/532 [09:55<28:22,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 134/532 [10:00<28:21,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 135/532 [10:05<30:59,  4.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 136/532 [10:10<30:43,  4.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 137/532 [10:14<29:14,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 138/532 [10:18<28:44,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 139/532 [10:24<31:27,  4.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▋       | 140/532 [10:28<30:25,  4.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 141/532 [10:32<28:53,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 142/532 [10:41<38:01,  5.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 143/532 [10:45<34:26,  5.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 144/532 [10:50<32:44,  5.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 145/532 [10:54<31:16,  4.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 146/532 [10:59<30:11,  4.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 147/532 [11:03<29:29,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 148/532 [11:07<28:06,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 149/532 [11:11<27:29,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 150/532 [11:16<28:36,  4.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 151/532 [11:20<27:30,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▊       | 152/532 [11:24<26:47,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 153/532 [11:28<27:02,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 154/532 [11:32<26:16,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 155/532 [11:36<26:26,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 156/532 [11:41<26:43,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 157/532 [11:45<25:41,  4.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 158/532 [11:49<26:18,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 159/532 [11:53<26:33,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 160/532 [11:57<25:49,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 161/532 [12:02<25:59,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 162/532 [12:06<26:06,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 163/532 [12:10<25:28,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 164/532 [12:16<28:58,  4.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 165/532 [12:22<31:54,  5.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 166/532 [12:26<29:44,  4.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███▏      | 167/532 [12:31<29:23,  4.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 168/532 [12:35<27:34,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 169/532 [12:39<26:25,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 170/532 [12:44<26:54,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 171/532 [12:48<26:33,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 172/532 [12:52<26:00,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 173/532 [12:56<25:56,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 174/532 [13:00<25:02,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 175/532 [13:05<25:19,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 176/532 [13:09<25:52,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 177/532 [13:13<24:57,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 178/532 [13:17<24:51,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▎      | 179/532 [13:22<25:38,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 180/532 [13:29<30:38,  5.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 181/532 [13:35<30:42,  5.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 182/532 [13:39<29:02,  4.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 183/532 [13:43<27:46,  4.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 184/532 [13:47<26:35,  4.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 185/532 [13:58<36:51,  6.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 186/532 [14:04<36:42,  6.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 187/532 [14:09<33:10,  5.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 188/532 [14:13<30:11,  5.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 189/532 [14:17<28:11,  4.93s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 190/532 [14:21<27:03,  4.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 191/532 [14:25<26:01,  4.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 192/532 [14:31<26:45,  4.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▋      | 193/532 [14:36<27:57,  4.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▋      | 194/532 [14:40<26:01,  4.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 195/532 [14:44<24:40,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 196/532 [14:48<25:02,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 197/532 [14:53<24:44,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 198/532 [14:58<25:25,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 199/532 [15:15<47:23,  8.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 200/532 [15:19<39:31,  7.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 201/532 [15:28<41:43,  7.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 202/532 [15:33<38:26,  6.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 203/532 [15:38<34:17,  6.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 204/532 [15:42<30:36,  5.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▊      | 205/532 [15:46<28:08,  5.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▊      | 206/532 [15:51<27:46,  5.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 207/532 [15:56<26:49,  4.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 208/532 [16:00<25:56,  4.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 209/532 [16:05<26:17,  4.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 210/532 [16:09<24:47,  4.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 211/532 [16:14<24:04,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 212/532 [16:19<25:28,  4.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 213/532 [16:23<23:57,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 214/532 [16:27<23:26,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 215/532 [16:31<22:57,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 216/532 [16:39<28:41,  5.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 217/532 [16:46<29:57,  5.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 218/532 [16:49<27:03,  5.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 219/532 [16:54<26:23,  5.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████▏     | 220/532 [16:58<24:49,  4.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 221/532 [17:02<23:19,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 222/532 [17:07<23:30,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 223/532 [17:11<22:43,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 224/532 [17:15<21:49,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 225/532 [17:20<22:29,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 226/532 [17:24<21:49,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 227/532 [17:28<21:24,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 228/532 [17:32<22:08,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 229/532 [17:37<21:43,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 230/532 [17:40<20:57,  4.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 231/532 [17:45<21:45,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▎     | 232/532 [17:50<22:53,  4.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 233/532 [17:54<22:08,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 234/532 [17:59<22:28,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 235/532 [18:03<21:25,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 236/532 [18:07<20:43,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 237/532 [18:16<28:01,  5.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 238/532 [18:20<25:27,  5.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 239/532 [18:25<24:42,  5.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 240/532 [18:29<23:11,  4.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 241/532 [18:33<21:50,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 242/532 [18:38<22:24,  4.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 243/532 [18:42<21:37,  4.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 244/532 [18:46<20:53,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 245/532 [18:51<21:23,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 246/532 [18:55<20:38,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▋     | 247/532 [18:59<20:54,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 248/532 [19:04<20:42,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 249/532 [19:07<19:57,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 250/532 [19:12<19:56,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 251/532 [19:16<20:05,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 252/532 [19:20<19:28,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 253/532 [19:24<19:09,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 254/532 [19:28<19:30,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 255/532 [19:33<19:45,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 256/532 [19:41<24:34,  5.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 257/532 [19:45<22:26,  4.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 258/532 [19:49<21:05,  4.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▊     | 259/532 [19:54<22:21,  4.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 260/532 [19:58<20:49,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 261/532 [20:02<19:52,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 262/532 [20:07<20:29,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 263/532 [20:11<19:21,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 264/532 [20:15<18:56,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 265/532 [20:19<19:16,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 266/532 [20:23<18:46,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 267/532 [20:27<18:30,  4.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 268/532 [20:32<19:38,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 269/532 [20:39<22:06,  5.04s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 270/532 [20:44<21:45,  4.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 271/532 [20:48<20:12,  4.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 272/532 [20:51<19:11,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████▏    | 273/532 [20:56<19:07,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 274/532 [21:00<18:41,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 275/532 [21:04<17:58,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 276/532 [21:08<18:23,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 277/532 [21:13<18:40,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 278/532 [21:17<17:55,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 279/532 [21:22<18:23,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 280/532 [21:26<18:25,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 281/532 [21:30<17:41,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 282/532 [21:35<18:46,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 283/532 [21:39<18:05,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 284/532 [21:43<17:16,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▎    | 285/532 [21:47<17:43,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 286/532 [21:52<18:04,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 287/532 [21:56<17:20,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 288/532 [22:00<17:40,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 289/532 [22:04<17:02,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 290/532 [22:08<16:52,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 291/532 [22:13<17:16,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 292/532 [22:17<16:41,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 293/532 [22:21<16:29,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 294/532 [22:26<16:55,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 295/532 [22:29<16:25,  4.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 296/532 [22:33<16:03,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 297/532 [22:38<16:30,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 298/532 [22:42<16:05,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 299/532 [22:46<15:50,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▋    | 300/532 [22:51<16:35,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 301/532 [22:54<16:04,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 302/532 [22:58<15:42,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 303/532 [23:03<16:38,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 304/532 [23:07<16:00,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 305/532 [23:12<16:02,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 306/532 [23:16<16:23,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 307/532 [23:21<16:52,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 308/532 [23:25<16:19,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 309/532 [23:30<17:03,  4.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 310/532 [23:34<16:26,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 311/532 [23:38<15:57,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▊    | 312/532 [23:43<16:09,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 313/532 [23:47<15:31,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 314/532 [23:50<14:34,  4.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 315/532 [23:59<19:41,  5.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 316/532 [24:03<18:08,  5.04s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 317/532 [24:09<18:49,  5.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 318/532 [24:13<17:19,  4.86s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 319/532 [24:17<16:54,  4.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 320/532 [24:22<16:26,  4.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 321/532 [24:26<15:31,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 322/532 [24:30<15:38,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 323/532 [24:36<16:44,  4.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 324/532 [24:40<15:59,  4.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 325/532 [24:45<15:50,  4.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████▏   | 326/532 [24:49<15:18,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████▏   | 327/532 [24:53<14:42,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 328/532 [24:57<15:10,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 329/532 [25:01<14:31,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 330/532 [25:05<14:02,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 331/532 [25:10<14:38,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 332/532 [25:14<14:13,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 333/532 [25:18<13:52,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 334/532 [25:22<13:57,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 335/532 [25:26<13:26,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 336/532 [25:30<13:13,  4.05s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 337/532 [25:35<13:36,  4.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▎   | 338/532 [25:39<13:23,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▎   | 339/532 [25:43<13:15,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 340/532 [25:47<13:34,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 341/532 [25:52<13:31,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 342/532 [25:56<13:14,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 343/532 [26:00<13:41,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 344/532 [26:05<14:20,  4.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 345/532 [26:12<16:12,  5.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 346/532 [26:16<14:55,  4.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 347/532 [26:20<14:12,  4.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 348/532 [26:25<14:16,  4.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 349/532 [26:29<13:38,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 350/532 [26:33<13:03,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 351/532 [26:38<13:20,  4.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 352/532 [26:42<12:52,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▋   | 353/532 [26:46<12:57,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 354/532 [26:51<13:10,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 355/532 [26:55<12:38,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 356/532 [26:59<12:18,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 357/532 [27:03<12:38,  4.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 358/532 [27:10<14:32,  5.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 359/532 [27:15<14:17,  4.96s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 360/532 [27:19<13:18,  4.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 361/532 [27:23<12:50,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 362/532 [27:27<12:55,  4.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 363/532 [27:32<12:57,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 364/532 [27:36<12:32,  4.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▊   | 365/532 [27:41<12:39,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 366/532 [27:45<12:01,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 367/532 [27:49<11:50,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 368/532 [27:54<12:33,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 369/532 [27:58<11:56,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 370/532 [28:03<11:59,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 371/532 [28:07<11:53,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 372/532 [28:11<11:37,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 373/532 [28:17<12:31,  4.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 374/532 [28:21<11:59,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 375/532 [28:25<11:26,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 376/532 [28:30<11:55,  4.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 377/532 [28:34<11:16,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 378/532 [28:39<11:23,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 379/532 [28:43<11:23,  4.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████▏  | 380/532 [28:47<11:01,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 381/532 [28:53<11:35,  4.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 382/532 [28:57<11:22,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 383/532 [29:01<10:53,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 384/532 [29:06<11:03,  4.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 385/532 [29:12<12:20,  5.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 386/532 [29:16<11:20,  4.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 387/532 [29:20<11:17,  4.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 388/532 [29:24<10:39,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 389/532 [29:29<10:44,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 390/532 [29:34<10:40,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 391/532 [29:37<10:07,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▎  | 392/532 [29:41<09:45,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 393/532 [29:46<10:09,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 394/532 [29:50<10:02,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 395/532 [29:54<09:45,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 396/532 [29:59<10:02,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▍  | 397/532 [30:03<09:34,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▍  | 398/532 [30:12<12:37,  5.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 399/532 [30:16<11:20,  5.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 400/532 [30:20<10:36,  4.82s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 401/532 [30:25<10:37,  4.86s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 402/532 [30:29<10:16,  4.74s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 403/532 [30:34<10:10,  4.74s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 404/532 [30:39<09:49,  4.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 405/532 [30:43<09:31,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▋  | 406/532 [30:48<09:38,  4.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 407/532 [30:52<09:17,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 408/532 [30:56<09:12,  4.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 409/532 [31:01<09:14,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 410/532 [31:05<08:50,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 411/532 [31:09<08:29,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 412/532 [31:16<10:27,  5.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 413/532 [31:20<09:33,  4.82s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 414/532 [31:24<08:56,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 415/532 [31:29<09:01,  4.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 416/532 [31:33<08:46,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 417/532 [31:37<08:25,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▊  | 418/532 [31:42<08:46,  4.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 419/532 [31:47<08:32,  4.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 420/532 [31:51<08:16,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 421/532 [31:55<08:06,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 422/532 [31:59<07:59,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 423/532 [32:04<07:50,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 424/532 [32:08<07:54,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 425/532 [32:12<07:34,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 426/532 [32:17<07:34,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 427/532 [32:21<07:35,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 428/532 [32:25<07:21,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 429/532 [32:29<07:23,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 430/532 [32:34<07:17,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 431/532 [32:37<06:57,  4.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 432/532 [32:43<07:19,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████▏ | 433/532 [32:47<07:04,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 434/532 [32:51<07:05,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 435/532 [32:56<07:11,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 436/532 [33:00<06:54,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 437/532 [33:03<06:34,  4.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 438/532 [33:08<06:43,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 439/532 [33:12<06:31,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 440/532 [33:18<07:12,  4.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 441/532 [33:23<07:07,  4.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 442/532 [33:27<06:40,  4.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 443/532 [33:30<06:20,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 444/532 [33:37<07:15,  4.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▎ | 445/532 [33:41<06:42,  4.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 446/532 [33:45<06:22,  4.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 447/532 [33:49<06:23,  4.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 448/532 [33:54<06:06,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 449/532 [34:00<06:51,  4.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 450/532 [34:04<06:29,  4.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 451/532 [34:08<06:04,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 452/532 [34:13<06:04,  4.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 453/532 [34:17<05:48,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 454/532 [34:21<05:30,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 455/532 [34:25<05:36,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 456/532 [34:29<05:23,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 457/532 [34:33<05:09,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 458/532 [34:38<05:15,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▋ | 459/532 [34:42<05:06,  4.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▋ | 460/532 [34:46<04:54,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 461/532 [34:50<04:58,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 462/532 [34:54<04:48,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 463/532 [34:58<04:51,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 464/532 [35:03<04:55,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 465/532 [35:07<04:41,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 466/532 [35:11<04:30,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 467/532 [35:17<05:11,  4.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 468/532 [35:22<05:03,  4.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 469/532 [35:27<05:03,  4.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 470/532 [35:31<04:43,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▊ | 471/532 [35:35<04:28,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▊ | 472/532 [35:40<04:31,  4.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 473/532 [35:44<04:15,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 474/532 [35:48<04:04,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 475/532 [35:52<04:09,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 476/532 [35:56<03:56,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 477/532 [36:00<03:53,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 478/532 [36:06<04:09,  4.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 479/532 [36:12<04:31,  5.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 480/532 [36:17<04:18,  4.97s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 481/532 [36:21<03:57,  4.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 482/532 [36:25<03:40,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 483/532 [36:30<03:49,  4.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 484/532 [36:34<03:37,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 485/532 [36:43<04:34,  5.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████▏| 486/532 [36:47<04:01,  5.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 487/532 [36:51<03:38,  4.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 488/532 [36:55<03:29,  4.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 489/532 [36:59<03:11,  4.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 490/532 [37:03<02:59,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 491/532 [37:08<03:00,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 492/532 [37:12<02:51,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 493/532 [37:16<02:44,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 494/532 [37:20<02:43,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 495/532 [37:24<02:37,  4.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 496/532 [37:29<02:36,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 497/532 [37:33<02:33,  4.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▎| 498/532 [37:37<02:23,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 499/532 [37:41<02:15,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 500/532 [37:45<02:11,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 501/532 [37:49<02:07,  4.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 502/532 [37:54<02:09,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 503/532 [37:58<02:06,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 504/532 [38:06<02:32,  5.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 505/532 [38:11<02:19,  5.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 506/532 [38:15<02:05,  4.82s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 507/532 [38:19<01:53,  4.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 508/532 [38:23<01:45,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 509/532 [38:27<01:40,  4.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 510/532 [38:31<01:32,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 511/532 [38:35<01:28,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 512/532 [38:40<01:24,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▋| 513/532 [38:44<01:19,  4.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 514/532 [38:48<01:14,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 515/532 [38:53<01:14,  4.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 516/532 [38:57<01:07,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 517/532 [39:01<01:03,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 518/532 [39:05<00:59,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 519/532 [39:09<00:53,  4.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 520/532 [39:13<00:48,  4.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 521/532 [39:17<00:45,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 522/532 [39:21<00:40,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 523/532 [39:25<00:36,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 524/532 [39:30<00:34,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▊| 525/532 [39:34<00:28,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 526/532 [39:37<00:24,  4.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 527/532 [39:42<00:21,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 528/532 [39:46<00:16,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 529/532 [39:50<00:12,  4.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 530/532 [39:54<00:08,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 531/532 [39:59<00:04,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|██████████| 532/532 [40:03<00:00,  4.52s/it]

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=1b5f261bfc7b8ad030972bec4e2b53127ed600407ac61b6532959f6bb1f7c016
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def evaluate_generated_comments(reference_comments, generated_comments):

    # Tokenize for BLEU
    tokenized_generated = [nltk.word_tokenize(comment.lower()) for comment in generated_comments]
    tokenized_reference = [[nltk.word_tokenize(ref.lower())] for ref in reference_comments]

    # BLEU-2
    bleu_score = corpus_bleu(tokenized_reference, tokenized_generated, weights=(0.5, 0.5))  # BLEU-2

    # ROUGE
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge1, rouge2, rougeL = 0, 0, 0
    for ref, gen in zip(reference_comments, generated_comments):
        scores = scorer.score(ref, gen)
        rouge1 += scores['rouge1'].fmeasure
        rouge2 += scores['rouge2'].fmeasure
        rougeL += scores['rougeL'].fmeasure
    rouge1 /= len(reference_comments)
    rouge2 /= len(reference_comments)
    rougeL /= len(reference_comments)

    # METEOR
    meteor = 0
    for ref, gen in zip(reference_comments, generated_comments):
        # Tokenize the hypothesis and references
        ref_tokens = nltk.word_tokenize(ref.lower())
        gen_tokens = nltk.word_tokenize(gen.lower())

        # Compute METEOR for each pair
        meteor += meteor_score([ref_tokens], gen_tokens)
    meteor /= len(reference_comments)

    return {
        'BLEU-2': bleu_score,
        'ROUGE-1': rouge1,
        'ROUGE-2': rouge2,
        'ROUGE-L': rougeL,
        'METEOR': meteor
    }

# %%
metrics = evaluate_generated_comments(reference_comments, generated_comments)
for metric, score in metrics.items():
    print(f"{metric}: {score:.4f}")
# Out:
# BLEU-2: 0.0668
# ROUGE-1: 0.1817
# ROUGE-2: 0.0563
# ROUGE-L: 0.1517
# METEOR: 0.1856

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a pre-trained Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Encode the comments to get their embeddings
embeddings_ref = model.encode(reference_comments)
embeddings_gen = model.encode(generated_comments)

# %%
# Compute cosine similarity for each pair
similarity_scores = cosine_similarity(embeddings_ref, embeddings_gen).diagonal()

# Calculate average similarity
average_similarity = similarity_scores.mean()



print(f"\nAverage Cosine Similarity: {average_similarity:.4f}")
# Out:
# Average Cosine Similarity: 0.5089

# %%
print(reference_comments[0])
print("__________")
print(generated_comments[0])
# Out:
# Returns a copy of the given array. The original array and the
# returned copy will have identical length and content.
#
# __________
# Copies the specified array, truncating or padding with nulls (if necessary)
# so the copy has the specified length. For all indices that are valid in both
# the original array and the copy, the two arrays will contain identical values.
# For any indices that are valid in the copy but not the original, the copy
# will contain nulls. Such indices will exist if and only if the specified length
# is greater than that of the original array.
# The resulting array
